# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.shape
# Out:
# (299, 13)

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.DEATH_EVENT.value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
sns.barplot(data= df, x = 'DEATH_EVENT', y = 'age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
sns.barplot(data = df, x = 'DEATH_EVENT', y = 'creatinine_phosphokinase')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='creatinine_phosphokinase'>

# %%
sns.barplot(data = df, x= 'DEATH_EVENT', y = 'ejection_fraction')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='ejection_fraction'>

# %%
sns.scatterplot(data=df , x = 'age', y = 'creatinine_phosphokinase')
# Out:
# <Axes: xlabel='age', ylabel='creatinine_phosphokinase'>

# %%
sns.scatterplot(data = df, x = 'age', y = 'ejection_fraction')
# Out:
# <Axes: xlabel='age', ylabel='ejection_fraction'>

# %%
sns.scatterplot(data = df, x = 'age', y = 'platelets')
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
# important visualization 
sns.violinplot(data = df, x = 'DEATH_EVENT', y = 'age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
# The relplot default scatter
sns.relplot(data = df, x = 'age', y = 'creatinine_phosphokinase')

# %%
# change the scatter by kind and write line
sns.relplot(data = df, x = 'age', y = 'creatinine_phosphokinase', kind = 'line')

# %%
sns.countplot(data = df , x = 'DEATH_EVENT')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
# To change the visual to horizontal put the variable x on y and vice versa
sns.countplot(data = df , y = 'DEATH_EVENT')
# Out:
# <Axes: xlabel='count', ylabel='DEATH_EVENT'>

# %%
sns.hls_palette(10)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.6832, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.41279999999999994, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.5167999999999995, 0.86),
#  (0.4752000000000003, 0.33999999999999997, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6207999999999999)]

# %%
sns.hls_palette(10, h = 0.01, l = 0.6, s= 0.65)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.6832, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.41279999999999994, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.5167999999999995, 0.86),
#  (0.4752000000000003, 0.33999999999999997, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6207999999999999)]

# %%
# improved more than boxplot
sns.boxenplot(data = df, y =  'age', x = 'DEATH_EVENT')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
sns.regplot(data = df, x = 'age', y = 'creatinine_phosphokinase')
# Out:
# <Axes: xlabel='age', ylabel='creatinine_phosphokinase'>

# %%
sns.regplot(data = df, x = 'age', y = 'ejection_fraction')
# Out:
# <Axes: xlabel='age', ylabel='ejection_fraction'>

# %%
sns.regplot(data = df, x = 'age', y = 'platelets')
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
sns.regplot(data = df, x = 'age', y = 'serum_creatinine')
# Out:
# <Axes: xlabel='age', ylabel='serum_creatinine'>

# %%
sns.regplot(data = df, x = 'age', y = 'serum_sodium')
# Out:
# <Axes: xlabel='age', ylabel='serum_sodium'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
pip install scikit-learn==1.2.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
X = df.drop('DEATH_EVENT', axis=1)
y = df['DEATH_EVENT']

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss
smk = SMOTETomek(random_state=42)
X_res, y_res = smk.fit_resample(X, y)

# %%
X_res.shape
# Out:
# (322, 12)

# %%
y_res.shape
# Out:
# (322,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.32, random_state = 42)

# %%
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(random_state = 42)
eec.fit(X_train, y_train)
# Out:
# EasyEnsembleClassifier(random_state=42)

# %%
y_pred = eec.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84        56
#            1       0.79      0.88      0.83        48
#
#     accuracy                           0.84       104
#    macro avg       0.84      0.84      0.84       104
# weighted avg       0.84      0.84      0.84       104

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[45, 11],
#        [ 6, 42]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8365384615384616

# %%
from sklearn.metrics import precision_score
precision_score(y_test, y_pred)
# Out:
# 0.7924528301886793

# %%
from sklearn.metrics import recall_score
recall_score(y_test, y_pred)
# Out:
# 0.875

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)
# Out:
# 0.8316831683168316

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.8392857142857143

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thersholds = roc_curve(y_test, y_pred)

# %%
fpr
# Out:
# array([0.        , 0.19642857, 1.        ])

# %%
tpr
# Out:
# array([0.   , 0.875, 1.   ])

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pred1 = lda.predict(X_test)

# %%
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83        56
#            1       0.78      0.83      0.81        48
#
#     accuracy                           0.82       104
#    macro avg       0.82      0.82      0.82       104
# weighted avg       0.82      0.82      0.82       104

# %%
print(accuracy_score(y_test, y_pred1))
# Out:
# 0.8173076923076923

# %%
print(precision_score(y_test, y_pred1))
# Out:
# 0.7843137254901961

# %%
print(f1_score(y_test, y_pred1))
# Out:
# 0.8080808080808081

# %%
print(recall_score(y_test, y_pred1))
# Out:
# 0.8333333333333334

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3 = knn.predict(X_test)

# %%
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.59      0.63        56
#            1       0.59      0.69      0.63        48
#
#     accuracy                           0.63       104
#    macro avg       0.64      0.64      0.63       104
# weighted avg       0.64      0.63      0.63       104

# %%
print(accuracy_score(y_test, y_pred3))
# Out:
# 0.6346153846153846

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
y_pred4 = etc.predict(X_test)

# %%
print(classification_report(y_test, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        56
#            1       0.79      0.92      0.85        48
#
#     accuracy                           0.85       104
#    macro avg       0.85      0.85      0.85       104
# weighted avg       0.86      0.85      0.85       104

# %%
print(accuracy_score(y_test, y_pred4))
# Out:
# 0.8461538461538461

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
gpc = GaussianProcessClassifier()
gpc.fit(X_train, y_train)
# Out:
# GaussianProcessClassifier()

# %%
y_pred5 = gpc.predict(X_test)

# %%
print(classification_report(y_test, y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.98      0.71        56
#            1       0.75      0.06      0.12        48
#
#     accuracy                           0.56       104
#    macro avg       0.65      0.52      0.41       104
# weighted avg       0.64      0.56      0.43       104

# %%
from sklearn.ensemble import BaggingClassifier
bc = BaggingClassifier()
bc.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
y_pred6 = bc.predict(X_test)

# %%
print(classification_report(y_test, y_pred6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        56
#            1       0.75      0.81      0.78        48
#
#     accuracy                           0.79       104
#    macro avg       0.79      0.79      0.79       104
# weighted avg       0.79      0.79      0.79       104

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
pac = PassiveAggressiveClassifier()
pac.fit(X_train, y_train)
# Out:
# PassiveAggressiveClassifier()

# %%
y_pred7 = pac.predict(X_test)

# %%
print(classification_report(y_test, y_pred7))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70        56
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.54       104
#    macro avg       0.27      0.50      0.35       104
# weighted avg       0.29      0.54      0.38       104

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(loss='hinge', penalty='l2', random_state=42)
sgd.fit(X_train, y_train)
y_pred8 = sgd.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred8))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70        56
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.54       104
#    macro avg       0.27      0.50      0.35       104
# weighted avg       0.29      0.54      0.38       104

# %%
print(accuracy_score(y_test, y_pred8))
# Out:
# 0.5384615384615384

# %%
from sklearn.linear_model import RidgeClassifier
ridge = RidgeClassifier(alpha = 1.0, random_state = 42)
ridge.fit(X_train, y_train)
# Out:
# RidgeClassifier(random_state=42)

# %%
y_pred9 = ridge.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred9))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83        56
#            1       0.78      0.83      0.81        48
#
#     accuracy                           0.82       104
#    macro avg       0.82      0.82      0.82       104
# weighted avg       0.82      0.82      0.82       104

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()
bnb.fit(X_train, y_train)
y_pred10 = bnb.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred10))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.46      0.56        56
#            1       0.55      0.77      0.64        48
#
#     accuracy                           0.61       104
#    macro avg       0.63      0.62      0.60       104
# weighted avg       0.63      0.61      0.60       104

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
base_estimator = DecisionTreeClassifier(max_depth=1)
ada = AdaBoostClassifier(base_estimator=base_estimator, n_estimators=50, random_state=42)
ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    random_state=42)

# %%
y_pred = ada.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88        56
#            1       0.84      0.90      0.87        48
#
#     accuracy                           0.88       104
#    macro avg       0.87      0.88      0.87       104
# weighted avg       0.88      0.88      0.88       104

# %%
from sklearn.svm import NuSVC
nusvc = NuSVC(nu = 0.5, kernel = 'rbf', random_state = 42)
nusvc.fit(X_train, y_train)
y_pred = nusvc.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.57      0.56        56
#            1       0.48      0.46      0.47        48
#
#     accuracy                           0.52       104
#    macro avg       0.51      0.51      0.51       104
# weighted avg       0.52      0.52      0.52       104

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes =(100,), activation = 'relu', solver = 'adam', random_state =42)
mlp.fit(X_train, y_train)
y_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        56
#            1       0.46      0.98      0.62        48
#
#     accuracy                           0.45       104
#    macro avg       0.23      0.49      0.31       104
# weighted avg       0.21      0.45      0.29       104
